# %%
import pandas as pd
import seaborn as sb

# %%
pwd
# Out:
# 'C:\\Users\\sarah\\PycharmProjects\\Da_sima'

# %%
con = pd.read_csv("data\Connections.csv")

# %%
con.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1363 entries, 0 to 1362
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   First Name     1323 non-null   str
#  1   Last Name      1323 non-null   str
#  2   Email Address  18 non-null     str
#  3   Company        1311 non-null   str
#  4   Position       1309 non-null   str
#  5   Connected On   1363 non-null   str
# dtypes: str(6)
# memory usage: 64.0 KB

# %%
con.head()
# Out:
#   First Name          Last Name Email Address  \
# 0        Liz          Dosovicky           NaN
# 1      Ronen  Tal-Botzer, Ph.D.           NaN
# 2      Tamir             Berler           NaN
# 3       Liav              Alter           NaN
# 4       Ofir            Kimberg           NaN
#
#                                       Company  \
# 0  WIZO Haifa Academy of Design and Education
# 1                               Evolution.Inc
# 2                               Self Employed
# 3          The Hebrew University of Jerusalem
# 4                       aQurate Software Ltd.
#
#                                             Position Connected On
# 0                                 Scheduling Manager    13-Nov-21
# 1                                      Founder & CEO    11-Nov-21
# 2                                         Consultant    04-Nov-21
# 3  Research Assistant, Data Scientist and Statist...    03-Nov-21
# 4                                    Product Manager    03-Nov-21

# %%
con['Connected On']= pd.to_datetime(con['Connected On'],datetime = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 con['Connected On']= pd.to_datetime(con['Connected On'],datetime = True)
#
# TypeError: to_datetime() got an unexpected keyword argument 'datetime'

# %%
con.tail()
# Out:
#      First Name    Last Name Email Address  \
# 1358      Assaf  Levy Hasdai           NaN
# 1359      Wendy      Zitzman           NaN
# 1360       Alex     Tsimbler           NaN
# 1361        Ziv        Gilad           NaN
# 1362       Alon        Basis           NaN
#
#                                    Company  \
# 1358                 EL AL Israel Airlines
# 1359                               Private
# 1360                                   CGI
# 1361  Self Employed Independent Consultant
# 1362          Biohealing - Renovating Life
#
#                                                Position  \
# 1358  Purser ( Inflight Service Manager ) and Head o...
# 1359                                         Consultant
# 1360                                 Network Consultant
# 1361  Microsoft Client Applications Professional, De...
# 1362                                       Founder, CEO
#
#                                       Connected On
# ...

# %%
mask = con['Connected On'] >= '2021-01-01'
con[mask].head(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 mask = con['Connected On'] >= '2021-01-01'
#       2 con[mask].head(5)
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\core\ops\common.py:85, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      82     other = sanitize_array(other, None)
#      83     other = ensure_wrapped_if_datetimelike(other)
# ---> 85 return method(self, other)
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\core\arraylike.py:62, in OpsMixin.__ge__(self, other)
#      60 @unpack_zerodim_and_defer("__ge__")
#      61 def __ge__(self, other):
# ---> 62     return self._cmp_method(other, operator.ge)
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\core\series.py:6735, in Series._cmp_method(self, other, op)
#    6732 lvalues = self._values
# ...
