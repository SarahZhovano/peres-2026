# %% [markdown]
# # PANDAS

# %% [markdown]
# WHAT IS PANDAS?

# %% [markdown]
# pandas is a Python package that provides fast, flexible, and expressive data structures designed to make working with "relational" or "labeled" data both easy and intuitive. It aims to be the fundamental high-level building block for doing practical, real world data analysis in Python. Additionally, it has the broader goal of becoming the most powerful and flexible open source data analysis / manipulation tool available in any language. It is already well on its way towards this goal.

# %% [markdown]
# What Can Pandas Do?

# %% [markdown]
# Pandas can cleaning the data like delete or insert rows ,
# contains wrong values, like empty or NULL values,
#  data alignment,group by functionality,

# %% [markdown]
# Installation of Pandas

# %% [markdown]
# C:\Users\Your Name>pip install pandas

# %% [markdown]
# # Import Pandas Package

# %%
from IPython import display
#display.Image(filename="I stand with israel.png")
image_filename = "I stand with israel.png"
width = 100
height = 100
display.Image(filename="I stand with israel.png", width=width, height=height)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 6
#       4 width = 100
#       5 height = 100
# ----> 6 display.Image(filename="I stand with israel.png", width=width, height=height)
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\IPython\core\display.py:1025, in Image.__init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata, alt)
#    1023 self.unconfined = unconfined
#    1024 self.alt = alt
# -> 1025 super(Image, self).__init__(data=data, url=url, filename=filename,
#    1026         metadata=metadata)
#    1028 if self.width is None and self.metadata.get('width', {}):
#    1029     self.width = metadata['width']
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\IPython\core\display.py:343, in DisplayObject.__init__(self, data, url, filename, metadata)
#     340 elif self.metadata is None:
#     341     self.metadata = {}
# --> 343 self.reload()
#     344 self._check_data()
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\IPython\core\display.py:1060, in Image.reload(self)
#    1058 """Reload the raw data from file or URL."""
#    1059 if self.embed:
# -> 1060     super(Image,self).reload()
#    1061     if self.retina:
#    1062         self._retina_shape()
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\IPython\core\display.py:369, in DisplayObject.reload(self)
#     367 if self.filename is not None:
#     368     encoding = None if "b" in self._read_flags else "utf-8"
# --> 369     with open(self.filename, self._read_flags, encoding=encoding) as f:
#     370         self.data = f.read()
#     371 elif self.url is not None:
#     372     # Deferred import
#
# FileNotFoundError: [Errno 2] No such file or directory: 'I stand with israel.png'

# %%
import pandas as pd

# %%
#Pandas work with Series or Data frame
#A Pandas Series is like a column in a table.
#A Pandas DataFrame is a table with rows and columns.

# %%
#all values in a series should have the same type. We can create a series by calling pandas.Series()
#Accessing Pandas Series by Using Index
#The values are labeled with their index number. The first value has index 0, the second value has index 1, etc.

# %%
a = [1, 7, 2]
myvar = pd.Series(a)
print(myvar)

# %%
type(a)

# %%
type(myvar)

# %%
print(myvar[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 print(myvar[1])
#
# NameError: name 'myvar' is not defined

# %%
a = [1, 7, 2]

myvar = pd.Series(a, index = ["x", "y", "z"])

print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
type(myvar)
# Out:
# pandas.Series

# %%
type(a)
# Out:
# list

# %%
print(myvar["y"])
# Out:
# 7

# %% [markdown]
# # Load Files Into a DataFrame

# %%
#A Pandas DataFrame is a 2 dimensional data structure, like a 2 dimensional array, or a table with rows and columns.

# %%
#Python method getcwd() returns current working directory of a process.
import os
os.getcwd()
# Out:
# 'C:\\Users\\sarah\\PycharmProjects\\Da_sima\\Pandas'

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %% [markdown]
# ### Load csv file

# %%
#Read data in the same directory that your python process is based or specify full path

# %%
df = pd.read_csv("customers.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df = pd.read_csv("customers.csv")
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     921 elif isinstance(handle, str):
#     922     # Check whether the filename is to be opened in binary mode.
#     923     # Binary mode does not support 'encoding' and 'newline'.
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#     925         # Encoding
# --> 926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#     929             encoding=ioargs.encoding,
#     930             errors=errors,
#     931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
#     935         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'customers.csv'

# %%
df

# %%
df.head()

# %%
type(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 type(df)
#
# NameError: name 'df' is not defined

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %%
pd.set_option('display.max_columns',4)
pd.set_option('display.max_rows',4)

# %%
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 print(df)
#
# NameError: name 'df' is not defined

# %%
products=pd.read_csv("Products.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 products=pd.read_csv("Products.csv")
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     921 elif isinstance(handle, str):
#     922     # Check whether the filename is to be opened in binary mode.
#     923     # Binary mode does not support 'encoding' and 'newline'.
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#     925         # Encoding
# --> 926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#     929             encoding=ioargs.encoding,
#     930             errors=errors,
#     931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
#     935         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Products.csv'

# %%
products=pd.read_csv(r"C:\Users\Sima\Documents\Sima\DA\02-Python\Pandas Python\data\Products.csv")

# %%
products

# %%
products.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 products.columns
#
# NameError: name 'products' is not defined

# %%
type(products)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 type(products)
#
# NameError: name 'products' is not defined

# %%
ct = pd.read_csv("data/Countries.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 ct = pd.read_csv("data/Countries.csv")
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     921 elif isinstance(handle, str):
#     922     # Check whether the filename is to be opened in binary mode.
#     923     # Binary mode does not support 'encoding' and 'newline'.
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#     925         # Encoding
# --> 926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#     929             encoding=ioargs.encoding,
#     930             errors=errors,
#     931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
#     935         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/Countries.csv'

# %%
ct

# %%
ct.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 ct.head()
#
# NameError: name 'ct' is not defined

# %%
ct.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 ct.head(10)
#
# NameError: name 'ct' is not defined

# %%
#Overriding Headers: Country Population Dataset

# %%
ct = pd.read_csv("data/Countries.csv",names=["yy","count","pop","world pop"])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 ct = pd.read_csv("data/Countries.csv",names=["yy","count","pop","world pop"])
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     921 elif isinstance(handle, str):
#     922     # Check whether the filename is to be opened in binary mode.
#     923     # Binary mode does not support 'encoding' and 'newline'.
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#     925         # Encoding
# --> 926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#     929             encoding=ioargs.encoding,
#     930             errors=errors,
#     931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
#     935         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/Countries.csv'

# %%
ct

# %%
#header=0: This parameter indicates that the header (column names) is in the 0th (first) row of the CSV file.

# %%
ct = pd.read_csv("data/Countries.csv",names=["yy","count","pop","world pop"],header=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 ct = pd.read_csv("data/Countries.csv",names=["yy","count","pop","world pop"],header=0)
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     921 elif isinstance(handle, str):
#     922     # Check whether the filename is to be opened in binary mode.
#     923     # Binary mode does not support 'encoding' and 'newline'.
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#     925         # Encoding
# --> 926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#     929             encoding=ioargs.encoding,
#     930             errors=errors,
#     931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
#     935         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/Countries.csv'

# %%
ct

# %%
#Import specific columns
ct = pd.read_csv("data/Countries.csv",names=["year","country","population"])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[43], line 2
#       1 #Import specific columns
# ----> 2 ct = pd.read_csv("data/Countries.csv",names=["year","country","population"])
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     921 elif isinstance(handle, str):
#     922     # Check whether the filename is to be opened in binary mode.
#     923     # Binary mode does not support 'encoding' and 'newline'.
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#     925         # Encoding
# --> 926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#     929             encoding=ioargs.encoding,
#     930             errors=errors,
#     931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
#     935         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/Countries.csv'

# %%
ct.head()

# %%
newname = ["year","country","population"]
ct = pd.read_csv("data/Countries.csv",names=newname)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[44], line 2
#       1 newname = ["year","country","population"]
# ----> 2 ct = pd.read_csv("data/Countries.csv",names=newname)
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     921 elif isinstance(handle, str):
#     922     # Check whether the filename is to be opened in binary mode.
#     923     # Binary mode does not support 'encoding' and 'newline'.
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#     925         # Encoding
# --> 926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#     929             encoding=ioargs.encoding,
#     930             errors=errors,
#     931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
#     935         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/Countries.csv'

# %%
ct.head()

# %%
newname = ["yy","country","population"]
ct = pd.read_csv("data/Countries.csv",names=newname,header=0,usecols=newname)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[45], line 2
#       1 newname = ["yy","country","population"]
# ----> 2 ct = pd.read_csv("data/Countries.csv",names=newname,header=0,usecols=newname)
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     921 elif isinstance(handle, str):
#     922     # Check whether the filename is to be opened in binary mode.
#     923     # Binary mode does not support 'encoding' and 'newline'.
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#     925         # Encoding
# --> 926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#     929             encoding=ioargs.encoding,
#     930             errors=errors,
#     931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
#     935         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/Countries.csv'

# %%
ct.head()

# %% [markdown]
# ### Seaborn Datasets

# %%
#Seaborn is a library for making statistical graphics in Python.

# %%
import seaborn as sb

# %%
sb.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
titanic = sb.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass  ... alive  alone
# 0           0       3  ...    no  False
# 1           1       1  ...   yes  False
# ..        ...     ...  ...   ...    ...
# 889         1       1  ...   yes   True
# 890         0       3  ...    no   True
#
# [891 rows x 15 columns]

# %%
diamonds =sb.load_dataset('diamonds')

# %%
diamonds
# Out:
#        carat      cut  ...     y     z
# 0       0.23    Ideal  ...  3.98  2.43
# 1       0.21  Premium  ...  3.84  2.31
# ...      ...      ...  ...   ...   ...
# 53938   0.86  Premium  ...  6.12  3.74
# 53939   0.75    Ideal  ...  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
tips =sb.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip  ...    time size
# 0         16.99  1.01  ...  Dinner    2
# 1         10.34  1.66  ...  Dinner    3
# ..          ...   ...  ...     ...  ...
# 242       17.82  1.75  ...  Dinner    2
# 243       18.78  3.00  ...  Dinner    2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### Read Excel files

# %%
#Import Data from Excel file
#pip install xlrd
#pip install --upgrade xlrd
#pip install openpyxl
#import xlrd
#import pandas as pd

# %%
orders = pd.read_excel('data\Orders.xlsx')
orders.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 orders = pd.read_excel('data\Orders.xlsx')
#       2 orders.head()
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\excel\_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
#     483         storage_options=storage_options,
#     484         engine=engine,
#     485         engine_kwargs=engine_kwargs,
#     486     )
#     487 elif engine and engine != io.engine:
#     488     raise ValueError(
#     489         "Engine should not be specified when passing "
#     490         "an ExcelFile - ExcelFile already has the engine set"
#     491     )
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\excel\_base.py:1604, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1601         ext = "xls"
#    1603 if ext is None:
# -> 1604     ext = inspect_excel_format(
#    1605         content_or_path=path_or_buffer, storage_options=storage_options
#    1606     )
#    1607     if ext is None:
#    1608         raise ValueError(
#    1609             "Excel file format cannot be determined, you must specify "
#    1610             "an engine manually."
#    1611         )
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\excel\_base.py:1452, in inspect_excel_format(content_or_path, storage_options)
#    1417 def inspect_excel_format(
#    1418     content_or_path: FilePath | ReadBuffer[bytes],
#    1419     storage_options: StorageOptions | None = None,
#    1420 ) -> str | None:
#    1421     """
#    1422     Inspect the path or content of an excel file and get its format.
#    1423
#    (...)   1450         If resulting stream does not have an XLS signature and is not a valid zipfile.
#    1451     """
# -> 1452     with get_handle(
#    1453         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1454     ) as handle:
#    1455         stream = handle.handle
#    1456         stream.seek(0)
#
# File ~\PycharmProjects\pythonProject3\venv\Lib\site-packages\pandas\io\common.py:935, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#    (...)    931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
# --> 935         handle = open(handle, ioargs.mode)
#     936     handles.append(handle)
#     938 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data\\Orders.xlsx'

# %% [markdown]
# ### Connection to database mssql

# %%
# %pip install pyodbc sqlalchemy
# %pwd
# Out:
# Requirement already satisfied: pyodbc in c:\users\sarah\pycharmprojects\pythonproject3\venv\lib\site-packages (5.3.0)
# Collecting sqlalchemy
#   Obtaining dependency information for sqlalchemy from https://files.pythonhosted.org/packages/58/d5/dd767277f6feef12d05651538f280277e661698f617fa4d086cce6055416/sqlalchemy-2.0.48-cp311-cp311-win_amd64.whl.metadata
#   Downloading sqlalchemy-2.0.48-cp311-cp311-win_amd64.whl.metadata (9.8 kB)
# Collecting greenlet>=1 (from sqlalchemy)
#   Obtaining dependency information for greenlet>=1 from https://files.pythonhosted.org/packages/f1/3a/efb2cf697fbccdf75b24e2c18025e7dfa54c4f31fab75c51d0fe79942cef/greenlet-3.3.2-cp311-cp311-win_amd64.whl.metadata
#   Downloading greenlet-3.3.2-cp311-cp311-win_amd64.whl.metadata (3.8 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\sarah\pycharmprojects\pythonproject3\venv\lib\site-packages (from sqlalchemy) (4.15.0)
# Downloading sqlalchemy-2.0.48-cp311-cp311-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    - -------------------------------------- 0.1/2.1 MB 825.8 kB/s eta 0:00:03
#    -- ------------------------------------- 0.1/2.1 MB 939.4 kB/s eta 0:00:03
#    ---- ----------------------------------- 0.2/2.1 MB 1.4 MB/s eta 0:00:02
#    -------- ------------------------------- 0.5/2.1 MB 2.2 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.6/2.1 MB 2.2 MB/s eta 0:00:01
#    ------------------ --------------------- 1.0/2.1 MB 3.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.2/2.1 MB 3.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.5/2.1 MB 3.9 MB/s eta 0:00:01
#    ------------------------------- -------- 1.7/2.1 MB 3.8 MB/s eta 0:00:01
#    -------------------------------------- - 2.1/2.1 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 4.0 MB/s eta 0:00:00
# Downloading greenlet-3.3.2-cp311-cp311-win_amd64.whl (230 kB)
#    ---------------------------------------- 0.0/230.4 kB ? eta -:--:--
#    ---------------------------------------- 230.4/230.4 kB 6.9 MB/s eta 0:00:00
# Installing collected packages: greenlet, sqlalchemy
# Successfully installed greenlet-3.3.2 sqlalchemy-2.0.48
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: C:\Users\sarah\PycharmProjects\pythonProject3\venv\Scripts\python.exe -m pip install --upgrade pip

# %%
#pip install pyodbc
#pip install SQLAlchemy
#import pyodbc
#con = pyodbc.connect(
#  host ="localhost",
#  user = "yourusername",
#  password = "yourpassword",
#  database ="mydatabase"
#)

#To find the ODBC driver name that you can use to export data to Pandas from SQL Server, you can check your ODBC Data Source Administrator. Follow these steps:
#On Windows:
#1.Open the Start menu and search for "ODBC Data Sources" or "ODBC Data Source Administrator."
#2.go to the "Drivers" tab. Here you'll find a list of installed ODBC drivers with their names.
#To retrieve the server name (instance name) run this query from sql server :SELECT @@SERVERNAME

# %%
import pyodbc
from sqlalchemy import create_engine

driver = "SQL Server"
server = "Sarah-Laptop\MSSQLSERVER22"
database = "Northwind"
trusted_connection = "yes"
conn =pyodbc.connect(f'Driver={{driver}};'
                     f'Server={server};'
                     f'Database={database};'
                     f'Trusted_Connection=yes;')

connection_string = f'mssql+pyodbc://{server}/{database}?trusted_connection={trusted_connection}&driver={driver}'
engine = create_engine(connection_string)
# Out:
#   Cell In[64], line 11
#     f'Trusted_Connection=yes;')
#                               ^
# SyntaxError: f-string expression part cannot include a backslash

# %% [markdown]
# #Connect to SQL Server Database with SQLAlchemy:
# #import pyodbc
# #from sqlalchemy import create_engine
# #driver = 'SQL Server Native Client 11.0'
# #server = 'localhost'
# #database = 'Northwind'
# #trusted_connection = 'yes'
# #connection_string = f'mssql+pyodbc://{server}/{database}?trusted_connection={trusted_connection}&driver={driver}'
# #engine = create_engine(connection_string)

# %%
df = pd.read_sql("select * from Products",conn)
# Out:
# C:\Users\sarah\AppData\Local\Temp\ipykernel_5864\500196871.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("select * from Products",conn)

# %%
df

# %% [markdown]
# ## General information

# %%
#df.shape
#df.head()
#df.tail()
#df.info()
#df.describe()

# %%
products

# %%
products.columns

# %%
products.values

# %%
products.shape

# %%
len(products)

# %%
#columns* rows
products.size

# %%
products.info()

# %%
products.head()

# %%
products.head(5)

# %%
products.tail(5)

# %% [markdown]
# ### Display specific columns

# %%
#2 Options to select columns
#df.column
#df['column']

# %%
products["ProductName"].head()

# %%
products.UnitPrice.head()

# %%
price =products.UnitPrice

# %%
price

# %%
#series 
type(price)

# %%
price.head()

# %%
price.shape

# %%
price.values

# %%
price.describe()

# %%
products.head()

# %%
products["ProductName"].head()

# %%
products["ProductName"].describe()

# %%
type(products["ProductName"])

# %%
products[["ProductName","UnitPrice"]].head()

# %%
type(products)

# %%
type(products["ProductName"].head())

# %%
#to_frame --Convert Series to DataFrame.
# or use [[]]
# DataFrame objects can have different data types. 
#Series --– All elements must be of same data type.

# %%
products["ProductName"].to_frame()

# %%
type(products["ProductName"].to_frame().head())

# %%
products[["ProductName"]].head()

# %%
type(products[["ProductName"]].head())

# %%
type(products[["UnitPrice"]])

# %%
#Calculation -- + - * /

# %%
products[["UnitPrice"]].head(5)+10

# %%
(products[["UnitPrice"]]-10).head(5)

# %%
products[["UnitPrice"]].head(5)-10

# %%
products[["UnitPrice"]].head(5)*1.17

# %%
column = ["ProductID","ProductName","UnitPrice"]
products[column].head()

# %% [markdown]
# ### Concatenation

# %%
(products["ProductName"].head(5)+' '+str(products["UnitPrice"].head(5))).to_frame()

# %%
products["ProductName"].head(5) + ' ' + products["UnitPrice"].astype(str).head(5)

# %%
(products["ProductName"].head(5) + ' ' + products["UnitPrice"].head(5).astype(str)).to_frame()

# %%
a

# %%
type(a)

# %%
df = pd.read_sql("select LastName,FirstName from Employees",conn)

# %%
df

# %%
type(df)

# %%
df[["LastName","FirstName"]].head(3)

# %%
(df["LastName"]+' '+df["FirstName"]).to_frame()

# %% [markdown]
# ### Rename Columns

# %%
# * List =   [] read/write
# * Tuples = () read only
# * Dictionaries{key:value,key:value}

# %%
df[["LastName","FirstName"]].rename(columns = {"LastName":"LName","FirstName":"FName"})

# %%
(df["LastName"]+' '+df["FirstName"]).to_frame(name="FullName")

# %% [markdown]
# ### Distinct ---drop_duplicates

# %%
df_loc = pd.read_sql("select Country, City from employees",conn)

# %%
df_loc

# %%
df_loc.drop_duplicates()

# %%
df_loc[["Country"]].drop_duplicates()

# %%
df_loc

# %% [markdown]
# ### Add New column

# %%
products.head(5)

# %%
products["After Tax"] = products["UnitPrice"]*1.17

# %%
products.head()

# %%
products.assign(Total=products["UnitPrice"]*1.17).head(5)

# %%
products.head()

# %% [markdown]
# ### Add column to specific location

# %%
products.insert(3,'Total',products["UnitPrice"]*1.17)

# %%
products.head()

# %%
products.assign(Discount=products["UnitPrice"]*0.1,
                 AfterDiscount=products["UnitPrice"]-products["UnitPrice"]*0.1).head()

# %%
products.head()

# %%
products.drop(columns ="Total")

# %%
products.head()

# %%
products.drop(["Total"],axis=1).head()

# %%
products.head()

# %% [markdown]
# ### pop out a column from the dataframe

# %%
#df.pop(column)
#del df[column]

# %%
#Return item and drop from frame.
products.pop("Total")

# %%
products.head()

# %%
products["Total"]=products["UnitPrice"]*1.17

# %%
products.head()

# %%
del products["Total"]

# %%
products.head()

# %%
titanic.head()

# %%
#pandas.DataFrame.drop

# %%
#Remove rows or columns by specifying label names and corresponding axis, or by specifying directly index or column names.
drop_row=titanic.drop(0)

# %%
drop_row.head()

# %%
#axis = 1 or columns
drop_col=titanic.drop(labels="deck",axis=1)

# %%
drop_col.head()

# %%
drop_col=titanic.drop(labels=["deck","who","embarked"],axis="columns")

# %%
drop_col.head()

# %%
#To cahnge original dataframe

# %%
titanic

# %%
titanic.drop(labels="deck",axis=1, inplace=True)

# %%
titanic.head()

# %%
#short way drop columns

# %%
titanic.drop(columns=["sibsp","parch","who"])

# %% [markdown]
# ### replace method

# %%
titanic["sex"].replace("female","F")

# %%
titanic["sex"].replace(["female","male"],["f","m"])

# %%
titanic

# %%
titanic["sex"].replace(["female","male"],["f","m"],inplace=True)

# %%
titanic

# %%
titanic.info()
